# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame
from datetime import datetime
#%matplotlib notebook

# %%
data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']
data.head()
# Out:
#                SPX
# 1990-02-01  328.79
# 1990-02-02  330.92
# 1990-02-05  331.85
# 1990-02-06  329.66
# 1990-02-07  333.75

# %%
fig, ax = plt.subplots()
spx.plot(ax=ax, grid=True, style='k-')


crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date)+5),
               xytext=(date, spx.asof(date)+150),
               arrowprops=dict(facecolor='red'))
              

#zoom en 2007-2009
ax.set_xlim(['30/7/2007', '30/3/2009'])
ax.set_ylim([600, 1800])

ax.set_title('Fechas importantes entre 2007 - 2008 en las crisis financieras',
            fontdict={'fontsize': 10,
                 'fontweight' :'extra bold',
                 'verticalalignment':'baseline'})
# Out:
# <img src="data:image/png;base64,..." width="509.44">
# Text(0.5,1,'Fechas importantes entre 2007 - 2008 en las crisis financieras')

# %%
plt.savefig('file.png')
